# %% [markdown]
# # Exercícios
#
# ## 1. Tamanho do Pedido de Compras
#
# Nesse exercício vamos avaliar o estoque de uma empresa. Vamos considerar que todos os produtos dessa empresa são comprados em lotes de 500 unidades.
#
# - Caso o estoque esteja abaixo de 1000 unidades, devemos fazer um pedido de 500 unidades.
# - Caso o estoque esteja abaixo de 200 unidades, devemos fazer um pedido de 1000 unidades.
#
# Defina o valor a ser pedido de cada produto para enviar ao time de compras.

# %%
estoque = [('BSA2199',396),('PPF5239',251),('BSA1212',989),('PPF2154',449),('BEB3410',241),('PPF8999',527),('EMB9591',601),('BSA2006',314),('EMB3604',469),('EMB2070',733),('PPF9018',339),('PPF1468',906),('BSA5819',291),('PPF8666',850),('BEB2983',353),('BEB5877',456),('PPF5008',963),('PPF3877',185),('PPF7321',163),('BSA8833',644),('PPF4980',421),('PPF3063',757),('BSA2089',271),('BSA8398',180),('EMB4622',515),('EMB9814',563),('PPF3784',229),('PPF2398',270),('BEB3211',181),('PPF8655',459),('PPF1874',799),('PPF8789',126),('PPF6324',375),('EMB9290',883),('BSA5516',555),('BSA8451',243),('BSA8213',423)]

# %%
lista_pedido =[1000 if qtd < 200 else 500 for produto, qtd in estoque]
print(lista_pedido)
# Out:
# [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 1000, 1000, 500, 500, 500, 500, 1000, 500, 500, 500, 500, 1000, 500, 500, 1000, 500, 500, 500, 500, 500]

# %%
lista_pedido2 = [value for code, value in estoque]
print(lista_pedido2)
# Out:
# [396, 251, 989, 449, 241, 527, 601, 314, 469, 733, 339, 906, 291, 850, 353, 456, 963, 185, 163, 644, 421, 757, 271, 180, 515, 563, 229, 270, 181, 459, 799, 126, 375, 883, 555, 243, 423]

# %%
lista_estoque = [qtd + lista_pedido[i] for i, qtd in enumerate(lista_pedido2)]
print(lista_estoque)
# Out:
# [896, 751, 1489, 949, 741, 1027, 1101, 814, 969, 1233, 839, 1406, 791, 1350, 853, 956, 1463, 1185, 1163, 1144, 921, 1257, 771, 1180, 1015, 1063, 729, 770, 1181, 959, 1299, 1126, 875, 1383, 1055, 743, 923]

# %%
estoque_att = []
for item, qtd in estoque:
  for att in lista_estoque:
    estoque_att.append((item, att))
print(estoque_att)
# Out:
# [('BSA2199', 896), ('BSA2199', 751), ('BSA2199', 1489), ('BSA2199', 949), ('BSA2199', 741), ('BSA2199', 1027), ('BSA2199', 1101), ('BSA2199', 814), ('BSA2199', 969), ('BSA2199', 1233), ('BSA2199', 839), ('BSA2199', 1406), ('BSA2199', 791), ('BSA2199', 1350), ('BSA2199', 853), ('BSA2199', 956), ('BSA2199', 1463), ('BSA2199', 1185), ('BSA2199', 1163), ('BSA2199', 1144), ('BSA2199', 921), ('BSA2199', 1257), ('BSA2199', 771), ('BSA2199', 1180), ('BSA2199', 1015), ('BSA2199', 1063), ('BSA2199', 729), ('BSA2199', 770), ('BSA2199', 1181), ('BSA2199', 959), ('BSA2199', 1299), ('BSA2199', 1126), ('BSA2199', 875), ('BSA2199', 1383), ('BSA2199', 1055), ('BSA2199', 743), ('BSA2199', 923), ('PPF5239', 896), ('PPF5239', 751), ('PPF5239', 1489), ('PPF5239', 949), ('PPF5239', 741), ('PPF5239', 1027), ('PPF5239', 1101), ('PPF5239', 814), ('PPF5239', 969), ('PPF5239', 1233), ('PPF5239', 839), ('PPF5239', 1406), ('PPF5239', 791), ('PPF5239', 1350), ('PPF5239', 853), ('PPF5239', 956), ('PPF5239', 1463), ('PPF5239', 1185), ('PPF5239', 1163), ('PPF5239', 1144), ('PPF5239', 921), ('PPF5239', 1257), ('PPF5239', 771