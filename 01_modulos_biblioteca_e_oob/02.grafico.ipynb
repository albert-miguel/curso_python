# %%
import matplotlib.pyplot as plt

vendas = [123, 414, 412, 131, 123, 234, 124, 341, 123, 234, 234, 111]
meses= ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'out', 'set', 'nov', 'dez']

plt.plot(meses, vendas)
plt.ylabel('Vendas')
plt.xlabel('Meses')
plt.axis([0, 11, 100, max(vendas)])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()
