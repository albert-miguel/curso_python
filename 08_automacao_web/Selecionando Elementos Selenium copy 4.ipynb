# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=servico)
driver.get('file:///home/albert/project/python/curso_py/08_automacao_web/Pagina%20Hashtag.html')

# %%
atributo = driver.find_element(By.XPATH, '/html/body/section[2]/div/div[4]/figure/a').get_attribute('href')
print(atributo)
# Out:
# https://www.hashtagtreinamentos.com/curso-de-excel-online

# %%
img = driver.find_element(By.XPATH, '/html/body/section[2]/div/div[8]/figure/a/img').get_attribute('src')
print(img)
# Out:
# file:///home/albert/project/python/curso_py/08_automacao_web/Pagina%20Hashtag_files/Box-Python-Impressionador-1024x576.png.webp
