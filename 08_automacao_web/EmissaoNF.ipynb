# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select

servico = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=servico)
driver.get('file:///home/albert/project/python/curso_py/08_automacao_web/login.html')

# %%
driver.find_element(By.XPATH, '/html/body/div/form/input[1]').send_keys('miguelzao')
driver.find_element(By.XPATH, '/html/body/div/form/input[2]').send_keys('1234')
driver.find_element(By.XPATH, '/html/body/div/form/button').click()

# %%
driver.find_element(By.XPATH, '//*[@id="nome"]').send_keys('Miguel Alberto')
driver.find_element(By.XPATH, '/html/body/div/form/input[2]').send_keys('Rua Joaquin martins')
driver.find_element(By.XPATH, '/html/body/div/form/input[3]').send_keys('Bairro tamati')
driver.find_element(By.XPATH, '/html/body/div/form/input[4]').send_keys('Piripiri')
driver.find_element(By.XPATH, '/html/body/div/form/input[5]').send_keys('64260-000')
driver.find_element(By.XPATH, '//*[@id="formulario"]/select').send_keys('PI')
driver.find_element(By.XPATH, '/html/body/div/form/input[6]').send_keys('74638546986')
driver.find_element(By.XPATH, '/html/body/div/form/input[7]').send_keys('?')
driver.find_element(By.XPATH, '//*[@id="formulario"]/input[8]').send_keys('Xícara')
driver.find_element(By.XPATH, '//*[@id="formulario"]/input[9]').send_keys(777)
driver.find_element(By.XPATH, '//*[@id="formulario"]/input[10]').send_keys(0.99)
driver.find_element(By.XPATH, '//*[@id="formulario"]/input[11]').send_keys(769.23)
driver.find_element(By.XPATH, '//*[@id="formulario"]/button').click()
